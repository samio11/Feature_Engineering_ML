# %%
import pandas as pd 
import numpy as nm 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("titanic_data.csv") 
data.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1       no  third
# 1            2      yes  first
# 2            3      yes  third
# 3            4      yes  first
# 4            5       no  third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
print(f"Features:-{data.shape[1]}") 
print(f"Rows:-{data.shape[0]}")
# Out:
# Features:-12
# Rows:-891

# %%
data.sample(10)
# Out:
#      PassengerId Survived  Pclass  \
# 154          155       no   third
# 199          200       no  second
# 298          299      yes   first
# 447          448      yes   first
# 757          758       no  second
# 641          642      yes   first
# 568          569       no   third
# 430          431      yes   first
# 718          719       no   third
# 710          711      yes   first
#
#                                                  Name     Sex   Age  SibSp  \
# 154                             Olsen, Mr. Ole Martin    male   NaN      0
# 199            Yrois, Miss. Henriette ("Mrs Harbeck")  female  24.0      0
# 298                             Saalfeld, Mr. Adolphe    male   NaN      0
# 447                       Seward, Mr. Frederic Kimber    male  34.0      0
# 757                          Bailey, Mr. Percy Andrew    male  18.0      0
# 641                              Sagesser, Mlle. Emma  female  24.0      0
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop_duplicates(inplace=True)

# %%
# Statistic Profiling

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Univerient Analysis

# %%
plt.title("Number of survived")
sns.countplot(data=data,x=data.Survived)
# Out:
# <Axes: title={'center': 'Number of survived'}, xlabel='Survived', ylabel='count'>

# %%
data.Survived.value_counts()
# Out:
# Survived
# no     549
# yes    342
# Name: count, dtype: int64

# %%
(data.Survived.value_counts()/len(data))*100
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
survive_count = data.Survived.value_counts()
survive_label=data.Survived.unique() 
plt.pie(survive_count,labels=survive_label,autopct="%1.1f") 
plt.title("Pie chart survive rate") 
plt.show()

# %%
sns.countplot(data=data,x=data.Pclass)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
data.Pclass.value_counts()
# Out:
# Pclass
# third     491
# first     216
# second    184
# Name: count, dtype: int64

# %%
(data.Pclass.value_counts()/len(data)) *100
# Out:
# Pclass
# third     55.106622
# first     24.242424
# second    20.650954
# Name: count, dtype: float64

# %%
sns.histplot(data.Age,bins=50)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(data=data,x=data.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(data=data,x=data.Fare,bins=50)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.kdeplot(data=data,x=data.Fare)
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.boxplot(data=data,x=data.Fare)
# Out:
# <Axes: xlabel='Fare'>

# %%
#Multiverient Analysis

# %%
sns.countplot(data=data,x=data.Sex,hue=data["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
gender_split = data.groupby("Sex")["Survived"].value_counts() 
gender_split
# Out:
# Sex     Survived
# female  yes         233
#         no           81
# male    no          468
#         yes         109
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x= data.Pclass,hue=data.Survived)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pclass_split = data.groupby("Pclass")["Survived"].value_counts(normalize=True)

# %%
pclass_split
# Out:
# Pclass  Survived
# first   yes         0.629630
#         no          0.370370
# second  no          0.527174
#         yes         0.472826
# third   no          0.757637
#         yes         0.242363
# Name: proportion, dtype: float64

# %%
data.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1       no  third
# 1            2      yes  first
# 2            3      yes  third
# 3            4      yes  first
# 4            5       no  third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(data=data,x=data.Pclass,y=data.Fare)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data=data,x=data.Survived,y=data.Age,hue="Sex")
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x=data.Survived,y=data.Age)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.kdeplot(x=data.Age,hue=data.Survived)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
data2 = sns.load_dataset("tips") 
data2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=data2,x=data2.total_bill,y=data2.tip,hue=data2.sex)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
pip install ydata_profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\samio\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\samio\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\samio\anaconda3\Lib\site-packages)

# %%
from ydata_profiling import ProfileReport 
profile = ProfileReport(data,title = "Titanic Profile Report") 
profile.to_file("samio.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
